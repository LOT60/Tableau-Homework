# %%
import pandas as pd

# %%
dataset = "Resources/201904-citibike-tripdata.csv"
df = pd.read_csv(dataset)
df.head()
# Out:
#    tripduration starttime  start station id stoptime  \
# 0           378   13:02.5               491  19:21.2
# 1           325   14:48.3              3235  20:13.3
# 2          1246   20:04.8              3511  40:51.4
# 3           614   22:37.9              3163  32:52.4
# 4           437   26:11.7               362  33:28.8
#
#                     start station name  start station latitude  \
# 0                 E 24 St & Park Ave S               40.740964
# 1                E 41 St & Madison Ave               40.752165
# 2  Adam Clayton Powell Blvd & W 115 St               40.802535
# 3          Central Park West & W 68 St               40.773407
# 4                   Broadway & W 37 St               40.751726
#
#    end station id  start station longitude                   end station name  \
# 0             485               -73.986022                    W 37 St & 5 Ave
# 1             362               -73.979922                 Broadway & W 37 St
# 2             281               -73.953242  Grand Army Plaza & Central Park S
# 3             362               -73.977825                 Broadway & W 37 St
# 4            3443               -73.987535                    W 52 St & 6 Ave
#
#    end station latitude  end station longitude  bikeid    usertype  \
# 0             40.750380             -73.983390   35084  Subscriber
# 1             40.751726             -73.987535   35052  Subscriber
# 2             40.764397             -73.973715   34362  Subscriber
# 3             40.751726             -73.987535   35327  Subscriber
# 4             40.761330             -73.979820   35052  Subscriber
#
#    birth year  gender
# 0        1968       1
# 1        1983       1
# 2        1984       1
# 3        1963       1
# 4        1972       1

# %%
df.dtypes
# Out:
# tripduration                 int64
# starttime                   object
# start station id             int64
# stoptime                    object
# start station name          object
# start station latitude     float64
# end station id               int64
# start station longitude    float64
# end station name            object
# end station latitude       float64
# end station longitude      float64
# bikeid                       int64
# usertype                    object
# birth year                   int64
# gender                       int64
# dtype: object

# %%
df["bikeid"].unique()
# Out:
# array([35084, 35052, 34362, 35327, 35589, 34207, 34086, 31853, 33758,
#        34820, 35095, 35376, 33890, 34848, 35293, 34262, 35086, 34026,
#        35193], dtype=int64)

# %%
bike_counts = df["bikeid"].value_counts()
bike_counts.head(10)
# Out:
# 35376    383
# 35193    380
# 35084    372
# 34848    369
# 35327    366
# 34086    364
# 35293    363
# 31853    355
# 35086    354
# 35121    353
# Name: bikeid, dtype: int64

# %%
df_ = df.copy()
df_["bikeid"] = df.loc[:,"bikeid"].astype(object)

# %%
df.dtypes
# Out:
# tripduration                 int64
# starttime                   object
# start station id             int64
# stoptime                    object
# start station name          object
# start station latitude     float64
# end station id               int64
# start station longitude    float64
# end station name            object
# end station latitude       float64
# end station longitude      float64
# bikeid                       int64
# usertype                    object
# birth year                   int64
# gender                       int64
# dtype: object

# %%
bikeid_df.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0            88  2019-04-01 00:00:14.7410  2019-04-01 00:01:42.8900
# 1           443  2019-04-01 00:00:20.8270  2019-04-01 00:07:44.2920
# 2           662  2019-04-01 00:00:30.9960  2019-04-01 00:11:33.2610
# 3            86  2019-04-01 00:00:30.9110  2019-04-01 00:01:56.9600
# 4           136  2019-04-01 00:00:32.5930  2019-04-01 00:02:49.3910
#
#    start station id      start station name  start station latitude  \
# 0              2006  Central Park S & 6 Ave               40.765909
# 1               254         W 11 St & 6 Ave               40.735324
# 2              3244  University Pl & E 8 St               40.731437
# 3               526         E 33 St & 5 Ave               40.747659
# 4               461         E 20 St & 2 Ave               40.735877
#
#    start station longitude  end station id         end station name  \
# 0               -73.976342            2006   Central Park S & 6 Ave
# 1               -73.998004             540  Lexington Ave & E 29 St
# 2               -73.994903            3244   University Pl & E 8 St
# 3               -73.984907             474          5 Ave & E 29 St
# 4               -73.982050             504          1 Ave & E 16 St
#
#    end station latitude  end station longitude  bikeid    usertype  \
# 0             40.765909             -73.976342   36515  Subscriber
# 1             40.743116             -73.982154   17406  Subscriber
# 2             40.731437             -73.994903   20775  Subscriber
# 3             40.745168             -73.986831   36270  Subscriber
# 4             40.732219             -73.981656   36051  Subscriber
#
#    birth year  gender
# 0        1982       1
# 1        1983       1
# 2        1988       1
# 3        1982       1
# 4        1986       1

# %%
birth_yr = bikeid_df.loc[bikeid_df["birth year"] == "1990", :]
birth_yr
# Out:
# C:\Users\annar\anaconda3\envs\PythonData\lib\site-packages\pandas\core\ops\array_ops.py:253: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   res_values = method(rvalues)
# Empty DataFrame
# Columns: [tripduration, starttime, stoptime, start station id, start station name, start station latitude, start station longitude, end station id, end station name, end station latitude, end station longitude, bikeid, usertype, birth year, gender]
# Index: []
